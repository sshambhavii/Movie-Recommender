# %%
import numpy as np
import pandas as pd
import json
import jsonpickle
import codecs

# %%
data = pd.read_csv('../Data/movie_metadata.csv')
data.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
# Add a new column with the name of `index`
data.reset_index(level=0, inplace=True)
# Rename the newly made column to `movie_id`
data.rename(columns={'index': 'movie_id'}, inplace=True)
data
# Out:
#       movie_id  color      director_name  num_critic_for_reviews  duration  \
# 0            0  Color      James Cameron                   723.0     178.0
# 1            1  Color     Gore Verbinski                   302.0     169.0
# 2            2  Color         Sam Mendes                   602.0     148.0
# 3            3  Color  Christopher Nolan                   813.0     164.0
# 4            4    NaN        Doug Walker                     NaN       NaN
# ...        ...    ...                ...                     ...       ...
# 5038      5038  Color        Scott Smith                     1.0      87.0
# 5039      5039  Color                NaN                    43.0      43.0
# 5040      5040  Color   Benjamin Roberds                    13.0      76.0
# 5041      5041  Color        Daniel Hsia                    14.0     100.0
# 5042      5042  Color           Jon Gunn                    43.0      90.0
#
# ...

# %%
df = data[['movie_id','movie_title', 'imdb_score','num_user_for_reviews','movie_imdb_link']].copy()
df.head()
# Out:
#    movie_id                                        movie_title  imdb_score  \
# 0         0                                            Avatar          7.9
# 1         1          Pirates of the Caribbean: At World's End          7.1
# 2         2                                           Spectre          6.8
# 3         3                             The Dark Knight Rises          8.5
# 4         4  Star Wars: Episode VII - The Force Awakens    ...         7.1
#
#    num_user_for_reviews                                    movie_imdb_link
# 0                3054.0  http://www.imdb.com/title/tt0499549/?ref_=fn_t...
# 1                1238.0  http://www.imdb.com/title/tt0449088/?ref_=fn_t...
# 2                 994.0  http://www.imdb.com/title/tt2379713/?ref_=fn_t...
# 3                2701.0  http://www.imdb.com/title/tt1345836/?ref_=fn_t...
# 4                   NaN  http://www.imdb.com/title/tt5289954/?ref_=fn_t...

# %%
C= df['imdb_score'].mean()
m= df['num_user_for_reviews'].quantile(0.9) #movies having vote count greater than 90% from the list will be taken
lists_movies = df.copy().loc[df['num_user_for_reviews'] >= m]
lists_movies
# Out:
#       movie_id                                movie_title  imdb_score  \
# 0            0                                    Avatar          7.9
# 1            1  Pirates of the Caribbean: At World's End          7.1
# 2            2                                   Spectre          6.8
# 3            3                     The Dark Knight Rises          8.5
# 5            5                               John Carter          6.6
# ...        ...                                        ...         ...
# 4821      4821                                 Halloween          7.9
# 4822      4822                              12 Angry Men          8.9
# 4860      4860                                      Cube          7.3
# 4914      4914                        The Man from Earth          8.0
# 4936      4936              The Texas Chain Saw Massacre          7.5
#
#       num_user_for_reviews                                    movie_imdb_link
# ...

# %%
def weighted_rating(x, m=m, C=C):
    v = x['num_user_for_reviews']
    R = x['imdb_score']
    # Calculation based on the IMDB formula (m=1838, c=6.09)
    return (v/(v+m) * R) + (m/(m+v) * C)

# %%
# Define a new feature 'score' and calculate its value with `weighted_rating()`
lists_movies['score'] = lists_movies.apply(weighted_rating, axis=1)
lists_movies.head(3)
# Out:
#    movie_id                                movie_title  imdb_score  \
# 0         0                                    Avatar          7.9
# 1         1  Pirates of the Caribbean: At World's End          7.1
# 2         2                                   Spectre          6.8
#
#    num_user_for_reviews                                    movie_imdb_link  \
# 0                3054.0  http://www.imdb.com/title/tt0499549/?ref_=fn_t...
# 1                1238.0  http://www.imdb.com/title/tt0449088/?ref_=fn_t...
# 2                 994.0  http://www.imdb.com/title/tt2379713/?ref_=fn_t...
#
#       score
# 0  7.650691
# 1  6.878130
# 2  6.661174

# %%
#Sort movies based on score calculated above
lists_movies = lists_movies.sort_values('score', ascending=False)

#Print the top 10 movies
list_movies_final=lists_movies[['movie_title','imdb_score']].head(15)

# %%
list_movies_final
# Out:
#                                             movie_title  imdb_score
# 1937                          The Shawshank Redemption          9.3
# 66                                     The Dark Knight          9.0
# 3466                                     The Godfather          9.2
# 270   The Lord of the Rings: The Fellowship of the R...         8.8
# 339      The Lord of the Rings: The Return of the King          8.9
# 683                                         Fight Club          8.8
# 654                                         The Matrix          8.7
# 97                                           Inception          8.8
# 3355                                      Pulp Fiction          8.9
# 340              The Lord of the Rings: The Two Towers          8.7
# 96                                        Interstellar          8.6
# 648                                Saving Private Ryan          8.6
# 3                                The Dark Knight Rises          8.5
# ...

# %%
list_movies_final.to_json('../Data/top_rated.json', orient = 'split', compression = 'infer')

# %%
import re
movie_list = []
for movie in df['movie_title']:
    x = re.sub(r"(\xa0|\362)", "", movie)
    movie_list.append(x)
movie_list
# Out:
# ['Avatar',
#  "Pirates of the Caribbean: At World's End",
#  'Spectre',
#  'The Dark Knight Rises',
#  'Star Wars: Episode VII - The Force Awakens            ',
#  'John Carter',
#  'Spider-Man 3',
#  'Tangled',
#  'Avengers: Age of Ultron',
#  'Harry Potter and the Half-Blood Prince',
#  'Batman v Superman: Dawn of Justice',
#  'Superman Returns',
#  'Quantum of Solace',
#  "Pirates of the Caribbean: Dead Man's Chest",
#  'The Lone Ranger',
#  'Man of Steel',
#  'The Chronicles of Narnia: Prince Caspian',
#  'The Avengers',
#  'Pirates of the Caribbean: On Stranger Tides',
#  'Men in Black 3',
#  'The Hobbit: The Battle of the Five Armies',
#  'The Amazing Spider-Man',
#  'Robin Hood',
#  'The Hobbit: The Desolation of Smaug',
#  'The Golden Compass',
#  'King Kong',
#  'Titanic',
#  'Captain America: Civil War',
#  'Battleship',
#  'Jurassic World',
#  'Skyfall',
#  'Spider-Man 2',
#  'Iron Man 3',
#  'Alice in Wonderland',
#  'X-Men: The Last Stand',
#  'Monsters University',
# ...
